# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import lit
from datetime import datetime
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, DecimalType

# %%
from IPython.core.display import HTML
display(HTML("<style>pre { white-space: pre !important; }</style>"))
# Out:
# <style>pre { white-space: pre !important; }</style>

# %%
warehouse_location = '/files'

# %%
spark = SparkSession \
    .builder \
    .appName("App de Spark para QQP") \
    .config("spark.sql.warehouse.dir", warehouse_location) \
    .enableHiveSupport() \
    .getOrCreate()
# Out:
# 24/05/29 20:52:17 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://cluster-r3d3-m.us-west1-a.c.bigdata-qqp2.internal:33111">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# !hdfs dfs -ls /user/QQP | head -n 6
# Out:
# Found 452 items
# -rw-r--r--   2 root hadoop  180751333 2024-05-28 16:20 /user/QQP/01-2023_01.csv
# -rw-r--r--   2 root hadoop  234811063 2024-05-28 16:14 /user/QQP/01-2023_02.csv
# -rw-r--r--   2 root hadoop  178013160 2024-05-28 15:47 /user/QQP/01-2024_01.csv
# -rw-r--r--   2 root hadoop  226158794 2024-05-28 15:46 /user/QQP/01-2024_02.csv
# -rw-r--r--   2 root hadoop   16997440 2024-05-28 15:45 /user/QQP/012015.csv

# %%
# %%time
# !hdfs dfs -count /user/QQP
# Out:
#            1          452        42911913094 /user/QQP
# CPU times: user 47.7 ms, sys: 16.8 ms, total: 64.5 ms
# Wall time: 3.62 s

# %%
schema = StructType([
    StructField("PRODUCTO", StringType(), True),
    StructField("PRESENTACIÓN", StringType(), True),
    StructField("MARCA", StringType(), True),
    StructField("CATEGORÍA", StringType(), True),
    StructField("CATÁLOGO", StringType(), True),
    StructField("PRECIO", DecimalType(18, 2), True),
    StructField("FECHAREGISTRO", StringType(), True),
    StructField("CADENACOMERCIAL", StringType(), True),
    StructField("GIRO", StringType(), True),
    StructField("NOMBRECOMERCIAL", StringType(), True),
    StructField("DIRECCIÓN", StringType(), True),
    StructField("ESTADO", StringType(), True),
    StructField("MUNICIPIO", StringType(), True),
    StructField("LATITUD", DecimalType(18, 6), True),
    StructField("LONGITUD", DecimalType(18, 6), True)
])

# %%
df = spark.read.csv('/user/QQP/', sep=',', header=False, schema=schema)

# %%
# Get the list of input files
file_list = df.inputFiles()
print("Number of input files: ", len(file_list))
# Out:
# Number of input files:  452

# %%
# %%time
df.count()
# Out:
# [Stage 2:>                                                          (0 + 1) / 1]
# CPU times: user 292 ms, sys: 34.5 ms, total: 327 ms
# Wall time: 3min 40s
# 136472358

# %%
df.show(10)
# Out:
# +---------------+--------------------+--------------+--------------------+------------+------+-------------+---------------+--------------------+--------------------+--------------------+--------------+--------------+---------+-----------+
# |       PRODUCTO|        PRESENTACIÓN|         MARCA|           CATEGORÍA|    CATÁLOGO|PRECIO|FECHAREGISTRO|CADENACOMERCIAL|                GIRO|     NOMBRECOMERCIAL|           DIRECCIÓN|        ESTADO|     MUNICIPIO|  LATITUD|   LONGITUD|
# +---------------+--------------------+--------------+--------------------+------------+------+-------------+---------------+--------------------+--------------------+--------------------+--------------+--------------+---------+-----------+
# |        A.S.COR|FRASCO GOTERO 24 ...|           S/M|        MEDICAMENTOS|MEDICAMENTOS|389.00|   2023-01-02|   MEGA SORIANA|SUPERMERCADO / TI...|MEGA SORIANA SUCU...|AGUASCALIENTES NT...|AGUASCALIENTES|AGUASCALIENTES|21.916001|-102.290779|
# |         ACEITE|BOTELLA 1 LT. VEG...|         1-2-3|ACEITES Y GRASAS ...|     BASICOS| 56.00|   2023-01-02|   MEGA SORIANA|SUPERMERCADO / TI...|MEGA SORIANA SUCU...|AGUASCALIENTES NT...|AGUASCALIENTES|AGUASCALIENTES|21.916001|-102.290779|
# |         ACEITE|BOTELLA 850 ML. V...|           AVE|ACEITES Y GRASAS ...|       PACIC| 39.00|   2023-01-02|   MEGA SORIANA|SUPERMERCADO / TI...|MEGA SORIANA SUCU...|AGUASCALIENTES NT...|AGUASCALIENTES|AGUASCALIENTES|21.916001|-102.290779|
# |         ACEITE|BOTELLA 946 ML. C...|        CANOIL|ACEITES Y GRASAS ...|     BASICOS| 50.90|   2023-01-02|   MEGA SORIANA|SUPERMERCADO / TI...|MEGA SORIANA SUCU...|AGUASCALIENTES NT...|AGUASCALIENTES|AGUASCALIENTES|21.916001|-102.290779|
# |         ACEITE|BOTELLA 840 ML. C...|       CAPULLO|ACEITES Y GRASAS ...|     BASICOS| 73.90|   2023-01-02|   MEGA SORIANA|SUPERMERCADO / TI...|MEGA SORIANA SUCU...|AGUASCALIENTES NT...|AGUASCALIENTES|AGUASCALIENTES|21.916001|-102.290779|
# |         ACEITE|BOTELLA 900 ML. V...|GRAN TRADICIÓN|ACEITES Y GRASAS ...|     BASICOS| 45.50|   2023-01-02|   MEGA SORIANA|SUPERMERCADO / TI...|MEGA SORIANA SUCU...|AGUASCALIENTES NT...|AGUASCALIENTES|AGUASCALIENTES|21.916001|-102.290779|
# |         ACEITE|BOTELLA 765 ML. MAÍZ|        MAZOLA|ACEITES Y GRASAS ...|     BASICOS| 71.50|   2023-01-02|   MEGA SORIANA|SUPERMERCADO / TI...|MEGA SORIANA SUCU...|AGUASCALIENTES NT...|AGUASCALIENTES|AGUASCALIENTES|21.916001|-102.290779|
# |         ACEITE|BOTELLA 800 ML. V...|    PRECISSIMO|ACEITES Y GRASAS ...|     BASICOS| 37.00|   2023-01-02|   MEGA SORIANA|SUPERMERCADO / TI...|MEGA SORIANA SUCU...|AGUASCALIENTES NT...|AGUASCALIENTES|AGUASCALIENTES|21.916001|-102.290779|
# |         ACEITE|BOTELLA 850 ML. V...|     SABROSANO|ACEITES Y GRASAS ...|     BASICOS| 46.90|   2023-01-02|   MEGA SORIANA|SUPERMERCADO / TI...|MEGA SORIANA SUCU...|AGUASCALIENTES NT...|AGUASCALIENTES|AGUASCALIENTES|21.916001|-102.290779|
# |ACEITE DE OLIVA|BOTELLA 750 ML. E...|     CARBONELL|PRODUCTOS DE TEMP...|     BASICOS|178.00|   2023-01-02|   MEGA SORIANA|SUPERMERCADO / TI...|MEGA SORIANA SUCU...|AGUASCALIENTES NT...|AGUASCALIENTES|AGUASCALIENTES|21.916001|-102.290779|
# +---------------+--------------------+--------------+--------------------+------------+------+-------------+---------------+--------------------+--------------------+--------------------+--------------+--------------+---------+-----------+
# only showing top 10 rows

# %%
df.write.mode('overwrite').saveAsTable('QQP')
# Out:
# ivysettings.xml file not found in HIVE_HOME or HIVE_CONF_DIR,/etc/hive/conf.dist/ivysettings.xml will be used
# 24/05/29 21:08:25 WARN SessionState: METASTORE_FILTER_HOOK will be ignored, since hive.security.authorization.manager is set to instance of HiveAuthorizerFactory.

# %%
spark.stop()
